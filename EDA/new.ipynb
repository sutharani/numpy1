# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\sudha\Downloads\archive (1)\student_admission_record_dirty.csv")
data
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
data.isnull().sum()
# Out:
# Name                      10
# Age                       10
# Gender                    10
# Admission Test Score      11
# High School Percentage    11
# City                      10
# Admission Status          10
# dtype: int64

# %%
data.head()
# Out:
#       Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0  Shehroz  24.0  Female                  50.0                   68.90
# 1    Waqar  21.0  Female                  99.0                   60.73
# 2   Bushra  17.0    Male                  89.0                     NaN
# 3    Aliya  17.0    Male                  55.0                   85.29
# 4    Bilal  20.0    Male                  65.0                   61.13
#
#         City Admission Status
# 0     Quetta         Rejected
# 1    Karachi              NaN
# 2  Islamabad         Accepted
# 3    Karachi         Rejected
# 4     Lahore              NaN

# %%
data.tail()
# Out:
#        Name   Age  Gender  Admission Test Score  High School Percentage  \
# 152     Ali  19.0  Female                  85.0                   78.09
# 153   Bilal  17.0  Female                  81.0                   84.40
# 154  Fatima  21.0  Female                  98.0                   50.86
# 155  Shoaib  -1.0    Male                  91.0                   80.12
# 156    Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 152     Quetta         Accepted
# 153  Islamabad         Rejected
# 154     Multan         Accepted
# 155     Quetta         Accepted
# 156     Lahore         Accepted

# %%
data.describe()
# Out:
#               Age  Admission Test Score  High School Percentage
# count  147.000000            146.000000              146.000000
# mean    19.680272             77.657534               75.684726
# std      4.540512             16.855343               17.368014
# min     -1.000000             -5.000000              -10.000000
# 25%     18.000000             68.250000               65.052500
# 50%     20.000000             79.000000               77.545000
# 75%     22.000000             89.000000               88.312500
# max     24.000000            150.000000              110.500000

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Admission Test Score',
#        'High School Percentage', 'City', 'Admission Status'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Name                       object
# Age                       float64
# Gender                     object
# Admission Test Score      float64
# High School Percentage    float64
# City                       object
# Admission Status           object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    147 non-null    object
#  1   Age                     147 non-null    float64
#  2   Gender                  147 non-null    object
#  3   Admission Test Score    146 non-null    float64
#  4   High School Percentage  146 non-null    float64
#  5   City                    147 non-null    object
#  6   Admission Status        147 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 8.7+ KB

# %%
data.nunique()
# Out:
# Name                       64
# Age                         9
# Gender                      2
# Admission Test Score       49
# High School Percentage    129
# City                        7
# Admission Status            2
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Length: 157, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(6)

# %%
data.isnull()
# Out:
#       Name    Age  Gender  Admission Test Score  High School Percentage  \
# 0    False  False   False                 False                   False
# 1    False  False   False                 False                   False
# 2    False  False   False                 False                    True
# 3    False  False   False                 False                   False
# 4    False  False   False                 False                   False
# ..     ...    ...     ...                   ...                     ...
# 152  False  False   False                 False                   False
# 153  False  False   False                 False                   False
# 154  False  False   False                 False                   False
# 155  False  False   False                 False                   False
# 156  False  False   False                 False                   False
#
#       City  Admission Status
# 0    False             False
# 1    False              True
# ...

# %%
data.isnull().sum()
# Out:
# Name                      10
# Age                       10
# Gender                    10
# Admission Test Score      11
# High School Percentage    11
# City                      10
# Admission Status          10
# dtype: int64

# %%
data['Admission Status']
# Out:
# 0      Rejected
# 1           NaN
# 2      Accepted
# 3      Rejected
# 4           NaN
#          ...
# 152    Accepted
# 153    Rejected
# 154    Accepted
# 155    Accepted
# 156    Accepted
# Name: Admission Status, Length: 157, dtype: object

# %%
data['Admission Status'].fillna('Accepted',inplace=True)
data
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
data.isnull().sum()
# Out:
# Name                      10
# Age                       10
# Gender                    10
# Admission Test Score      11
# High School Percentage    11
# City                      10
# Admission Status           0
# dtype: int64

# %%
data['City'].fillna('x',inplace=True)
data
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_11052\1658353479.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['City'].fillna('x',inplace=True)
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# ...

# %%
data.isnull().sum()
# Out:
# Name                      10
# Age                       10
# Gender                    10
# Admission Test Score      11
# High School Percentage    11
# City                       0
# Admission Status           0
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mean(), inplace=True)
data
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_11052\2167283640.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data['Age'].mean(), inplace=True)
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# ...

# %%
data.isnull().sum()
# Out:
# Name                      10
# Age                        0
# Gender                    10
# Admission Test Score      11
# High School Percentage    11
# City                       0
# Admission Status           0
# dtype: int64

# %%
data['Name'].fillna('ABC',inplace=True)
data
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_11052\97809858.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Name'].fillna('ABC',inplace=True)
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# ...

# %%
data.isnull().sum()
# Out:
# Name                       0
# Age                        0
# Gender                    10
# Admission Test Score      11
# High School Percentage    11
# City                       0
# Admission Status           0
# dtype: int64

# %%
data['High School Percentage'].mean()
# Out:
# np.float64(75.68472602739726)

# %%
data['High School Percentage'].fillna(data['High School Percentage'].mean(),inplace=True)
data
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_11052\3235791487.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['High School Percentage'].fillna(data['High School Percentage'].mean(),inplace=True)
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0               68.900000
# 1      Waqar  21.0  Female                  99.0               60.730000
# 2     Bushra  17.0    Male                  89.0               75.684726
# ...

# %%
data.isnull().sum()
# Out:
# Name                       0
# Age                        0
# Gender                    10
# Admission Test Score      11
# High School Percentage     0
# City                       0
# Admission Status           0
# dtype: int64

# %%
grouped_data=data.groupby('Gender')
grouped_count=grouped_data['Gender'].count()
grouped_count
# Out:
# Gender
# Female    83
# Male      64
# Name: Gender, dtype: int64

# %%
data['Admission Test Score'].mean()
# Out:
# np.float64(77.65753424657534)

# %%
data['Admission Test Score'].fillna(data['Admission Test Score'].mean(),inplace=True)
data
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_11052\2538600310.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Admission Test Score'].fillna(data['Admission Test Score'].mean(),inplace=True)
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0               68.900000
# 1      Waqar  21.0  Female                  99.0               60.730000
# 2     Bushra  17.0    Male                  89.0               75.684726
# ...

# %%
data.isnull().sum()
# Out:
# Name                       0
# Age                        0
# Gender                    10
# Admission Test Score       0
# High School Percentage     0
# City                       0
# Admission Status           0
# dtype: int64

# %%
data.drop(['Gender'],axis=1,inplace=True)
data
# Out:
#         Name   Age  Admission Test Score  High School Percentage       City  \
# 0    Shehroz  24.0                  50.0               68.900000     Quetta
# 1      Waqar  21.0                  99.0               60.730000    Karachi
# 2     Bushra  17.0                  89.0               75.684726  Islamabad
# 3      Aliya  17.0                  55.0               85.290000    Karachi
# 4      Bilal  20.0                  65.0               61.130000     Lahore
# ..       ...   ...                   ...                     ...        ...
# 152      Ali  19.0                  85.0               78.090000     Quetta
# 153    Bilal  17.0                  81.0               84.400000  Islamabad
# 154   Fatima  21.0                  98.0               50.860000     Multan
# 155   Shoaib  -1.0                  91.0               80.120000     Quetta
# 156     Maaz  17.0                  88.0               86.850000     Lahore
#
#     Admission Status
# 0           Rejected
# ...

# %%
data.isnull().sum()
# Out:
# Name                      0
# Age                       0
# Admission Test Score      0
# High School Percentage    0
# City                      0
# Admission Status          0
# dtype: int64

# %%
plt.figure(figsize=(8,6)) #plot size
sns.barplot(x='Age',y='High School Percentage',data=data,color='red',edgecolor='blue')
plt.title('Percentage vs Age')
plt.xlabel("Age")
plt.ylabel('High School Percentage')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data['High School Percentage'],bins=30,color="teal",kde=True)
plt.show()

# %%
sns.scatterplot(x='Age',y='High School Percentage',data=data,hue=data['City'])
plt.title("Relationship between Age vs High School Percentage")
plt.show()

# %%
sns.lineplot(x="Age",y="High School Percentage",data=data,marker='o',ls='-.')
# Out:
# <Axes: xlabel='Age', ylabel='High School Percentage'>

# %%
data=pd.read_csv(r"C:\Users\sudha\Downloads\archive (1)\student_admission_record_dirty.csv")
data
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
data['Gender'].mode()[0]
# Out:
# 'Female'

# %%
data['Gender']=data['Gender'].fillna(data['Gender'].mode()[0])

# %%
data
# Out:
#         Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0    Shehroz  24.0  Female                  50.0                   68.90
# 1      Waqar  21.0  Female                  99.0                   60.73
# 2     Bushra  17.0    Male                  89.0                     NaN
# 3      Aliya  17.0    Male                  55.0                   85.29
# 4      Bilal  20.0    Male                  65.0                   61.13
# ..       ...   ...     ...                   ...                     ...
# 152      Ali  19.0  Female                  85.0                   78.09
# 153    Bilal  17.0  Female                  81.0                   84.40
# 154   Fatima  21.0  Female                  98.0                   50.86
# 155   Shoaib  -1.0    Male                  91.0                   80.12
# 156     Maaz  17.0    Male                  88.0                   86.85
#
#           City Admission Status
# 0       Quetta         Rejected
# ...

# %%
data.isnull().sum()
# Out:
# Name                      10
# Age                       10
# Gender                     0
# Admission Test Score      11
# High School Percentage    11
# City                      10
# Admission Status          10
# dtype: int64

# %% [markdown]
# ## Univariate

# %%
import seaborn as sns
import numpy as np

# %%
flights = sns.load_dataset("flights")
df=sns.load_dataset("flights")
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.barplot(x='year',y='passengers',data=df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.barplot(x='year',y='passengers',data=df,estimator=np.std)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
# Count plot

# %%
sns.countplot(x='year',data=df)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
# Boxplot

# %%
sns.boxplot(x='year',y='passengers',data=df,palette="rainbow")
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5744\844689248.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='year',y='passengers',data=df,palette="rainbow")
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.boxplot(data=df,palette="rainbow")
# Out:
# <Axes: >

# %%
sns.boxplot(data=df,palette="rainbow",orient='h')
# Out:
# <Axes: >

# %%
# Bivariate

# %%
# Violin plot

# %%
sns.violinplot(x="year", y="passengers", data=df,palette='rainbow')
sns.swarmplot(x="year", y="passengers", data=df,color='black',size=3)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_5744\3559029368.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="year", y="passengers", data=df,palette='rainbow')
# <Axes: xlabel='year', ylabel='passengers'>

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
df=sns.load_dataset("diamonts")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 diamonds = sns.load_dataset("diamonds")
#       2 diamonds
# ----> 3 df=sns.load_dataset("diamonts")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\utils.py:573, in load_dataset(name, cache, data_home, **kws)
#     571 if not os.path.exists(cache_path):
#     572     if name not in get_dataset_names():
# --> 573         raise ValueError(f"'{name}' is not one of the example datasets.")
#     574     urlretrieve(url, cache_path)
#     575 full_path = cache_path
#
# ValueError: 'diamonts' is not one of the example datasets.
